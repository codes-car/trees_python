# %% [markdown]
# # Proyecto práctico: árbol de decision y random forest con scikit-learm

# %%
# Librerias necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Utilizaremos el Car Evaluation Data Set de Kaggle: https://www.kaggle.com/datasets/elikplim/car-evaluation-data-set?select=car_evaluation.csv

# %%
# Cargamos dataset a utilizar
